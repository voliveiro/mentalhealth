# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import timedelta
from datetime import datetime
import matplotlib.pyplot as plt

# %matplotlib inline

admits = pd.read_csv('IMHadmits.csv', sep = ',')

admits.head()
# Out:
#       Year  all_public   IMH
# 0  1987-01       18822   493
# 1  1987-02       19074   480
# 2  1987-03       22173   518
# 3  1987-04       19797   498
# 4  1987-05       19602   469

# %%
admits.shape
# Out:
# (254, 3)

# %%
admits.columns
# Out:
# Index([' Year', 'all_public', ' IMH'], dtype='object')

# %%
admits.rename(columns={' Year': "Year", ' IMH': "IMH",}, inplace=True)

# %%
admits.columns
# Out:
# Index(['Year', 'all_public', 'IMH'], dtype='object')

# %%
admits['Year'] = pd.to_datetime(admits.Year)
admits.set_index('Year', inplace=True)

# %%
admits
# Out:
#             all_public  IMH
# Year
# 1987-01-01       18822  493
# 1987-02-01       19074  480
# 1987-03-01       22173  518
# 1987-04-01       19797  498
# 1987-05-01       19602  469
# ...                ...  ...
# 2007-10-01       27743  766
# 2007-11-01       27133  782
# 2007-12-01       26318  646
# 2008-01-01       27966  732
# 2008-02-01       25575  724
#
# [254 rows x 2 columns]

# %%
admits.IMH.plot(kind="line")

# %%
admits['2006':'2008'].IMH.plot(kind="line")

# %%
from matplotlib import dates

x=psychadmits["year_month"]
y=psychadmits["IMH"]

fig=plt.figure(figsize=(20,5))
fig.add_axes([0,0,1,1])

plt.plot(x, y)


fig = plt.figure(figsize=(10,20))
#figure(num=None, figsize=(50, 20), dpi=80, facecolor='w', edgecolor='k')
