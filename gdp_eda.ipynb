# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

gdp = pd.read_csv('worldbank_sggdp.csv', sep = ',')

gdp.head()
# Out:
#   Country Name          1960          1961          1962          1963  \
# 0        Aruba           NaN           NaN           NaN           NaN
# 1  Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2       Angola           NaN           NaN           NaN           NaN
# 3      Albania           NaN           NaN           NaN           NaN
# 4      Andorra           NaN           NaN           NaN           NaN
#
#            1964          1965          1966          1967          1968  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#       ...               2010          2011          2012          2013  \
# ...

# %%
gdp.rename(columns={'Country Name':'Country',}, inplace=True)

# %%
gdp.head()
# Out:
#        Country          1960          1961          1962          1963  \
# 0        Aruba           NaN           NaN           NaN           NaN
# 1  Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2       Angola           NaN           NaN           NaN           NaN
# 3      Albania           NaN           NaN           NaN           NaN
# 4      Andorra           NaN           NaN           NaN           NaN
#
#            1964          1965          1966          1967          1968  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#       ...               2010          2011          2012          2013  \
# ...

# %%
mask=gdp.Country == "Singapore"
gdp_singapore=gdp[mask]
gdp_singapore

#this should only produce one row. ...
# Out:
#        Country          1960          1961          1962          1963  \
# 0    Singapore           NaN           NaN           NaN           NaN
# 1    Singapore  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2    Singapore           NaN           NaN           NaN           NaN
# 3    Singapore           NaN           NaN           NaN           NaN
# 4    Singapore           NaN           NaN           NaN           NaN
# 5    Singapore           NaN           NaN           NaN           NaN
# 6    Singapore           NaN           NaN           NaN           NaN
# 7    Singapore           NaN           NaN  2.445060e+10  1.827212e+10
# 8    Singapore           NaN           NaN           NaN           NaN
# 9    Singapore           NaN           NaN           NaN           NaN
# 10   Singapore           NaN           NaN           NaN           NaN
# 11   Singapore  1.857767e+10  1.965394e+10  1.989249e+10  2.150745e+10
# ...
